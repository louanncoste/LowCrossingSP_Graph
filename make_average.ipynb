# %%
import os
import re

def get_values(filename):
  """
  This function opens a file, searches for the sentence "Finished within Xsec, crossing number: Y",
  and extracts the values of X and Y.

  Args:
      filename: The path to the file.

  Returns:
      A tuple containing the values of X and Y, or None if the sentence is not found.
  """
  with open(filename, 'r') as f:
    for line in f:
      match = re.search(r"Finished within (\d+\.?\d*)sec, crossing number: (\d+)", line, flags=re.MULTILINE)
      if match:
        return float(match.group(1)), float(match.group(2))
  return None

def main():
  folder_path = "res/big_tests"
  file_pattern = r".*\.out$"  # Matches all files ending with ".out"

  # Dictionary to store results {filename_base: (X_sum, Y_sum, count)}
  results = {}
  for filename in os.listdir(folder_path):
    if re.match(file_pattern, filename):
      filepath = os.path.join(folder_path, filename)
      values = get_values(filepath)
      if values:
        filename_base = filename.rsplit('_', 1)[0]
        if filename_base not in results:
          results[filename_base] = (0, 0, 0)
        time, cnb = values
        results[filename_base] = (results[filename_base][0] + time, results[filename_base][1] + cnb, results[filename_base][2] + 1)

  # Print the averages for each filename base
  for filename_base, (time_sum, cnb_sum, count) in results.items():
    if count > 0:
      print(f"Filename: {filename_base}")
      print(f"Average Time taken: {time_sum / count} sec")
      print(f"Average Max Crossing Number: {cnb_sum / count}")
      #print(f"Filename: {filename_base}: {cnb_sum / count} & {time_sum / count} \\\ ")
      print()

if __name__ == "__main__":
  main()
# Out:
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist
# Average Time taken: 7.338999999999999 sec
# Average Max Crossing Number: 872.0
#
# Filename: dip20170205.edgelist
# Average Time taken: 1.299 sec
# Average Max Crossing Number: 203.6
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist
# Average Time taken: 15.917777777777777 sec
# Average Max Crossing Number: 886.8888888888889
#
# Filename: t.CAL-w.txt
# Average Time taken: 772.5888888888888 sec
# Average Max Crossing Number: 14.0
#
# Filename: epinions1-d.txt
# Average Time taken: 53.65 sec
# Average Max Crossing Number: 1150.8
#
# Filename: buddha-w.txt
# Average Time taken: 78.72666666666667 sec
# Average Max Crossing Number: 34.0
#
# Filename: y-BerkStan-d.txt
# Average Time taken: 7153.197999999999 sec
# Average Max Crossing Number: 1595.0
#
# Filename: CAIDA_as_20130601.edgelist
# Average Time taken: 33.651999999999994 sec
# Average Max Crossing Number: 899.9
#
# Filename: twitter_combined-d.txt
# Average Time taken: 78.74222222222221 sec
# Average Max Crossing Number: 1456.6666666666667
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist
# Average Time taken: 1.875 sec
# Average Max Crossing Number: 249.8
#
# Filename: oregon2_010331.txt
# Average Time taken: 1.781 sec
# Average Max Crossing Number: 318.2
#
# Filename: z-alue7065.txt
# Average Time taken: 0.44699999999999995 sec
# Average Max Crossing Number: 8.0
#
# Filename: ca-HepPh.edgelist
# Average Time taken: 0.65125 sec
# Average Max Crossing Number: 227.0
#
# Filename: t.FLA-w.txt
# Average Time taken: 242.202 sec
# Average Max Crossing Number: 16.0
#
# Filename: com-dblp.ungraph.txt
# Average Time taken: 76.61000000000001 sec
# Average Max Crossing Number: 308.0
#
# Filename: powerlaw2.5.txt
# Average Time taken: 3636.6288888888885 sec
# Average Max Crossing Number: 1162.0
#
# Filename: notreDame-d.txt
# Average Time taken: 543.5550000000001 sec
# Average Max Crossing Number: 856.6
#
# Filename: froz-w.txt
# Average Time taken: 144.033 sec
# Average Max Crossing Number: 16.0
#
# Filename: gnutella31-d.txt
# Average Time taken: 2.06625 sec
# Average Max Crossing Number: 98.5
#
# Filename: grid300-10.txt
# Average Time taken: 2.568888888888889 sec
# Average Max Crossing Number: 8.0
#
# Filename: p2p-Gnutella09.edgelist
# Average Time taken: 0.13800000000000004 sec
# Average Max Crossing Number: 148.3
#
# Filename: xgrid500-10.txt
# Average Time taken: 18.505 sec
# Average Max Crossing Number: 8.0
#
# Filename: facebook_combined.txt
# Average Time taken: 0.26111111111111107 sec
# Average Max Crossing Number: 173.55555555555554
#
# Filename: as-skitter.txt
# Average Time taken: 32207.96 sec
# Average Max Crossing Number: 10492.0

# %%
def get_sums(filename):
    with open(filename, 'r') as f:
        deg_sum=0
        cross_sum=0
        for line in f:
            linesplit = line.split()
            if len(linesplit) == 2:
                deg_sum+= int(linesplit[0])
                cross_sum+= int(linesplit[1])
            else:
                return None
    return (deg_sum, cross_sum)



def main():
  folder_path = "res/big_tests"
  file_pattern = r".*_deg_cross\.txt$"  

  results = {}
  for filename in os.listdir(folder_path):
    if re.match(file_pattern, filename):
      filepath = os.path.join(folder_path, filename)
      sums = get_sums(filepath)
      if sums:
        filename_base = filename.rsplit('__', 1)[0]
        if filename_base not in results:
          results[filename_base] = (0, 0, 0)
        deg_sum, cnb_sum = sums
        results[filename_base] = (results[filename_base][0] + deg_sum, results[filename_base][1] + cnb_sum, results[filename_base][2] + 1)

  # Print the averages for each filename base
  for filename_base, (sum_deg_sum, sum_cnb_sum, count) in results.items():
    if count > 0:
      print(f"Filename: {filename_base}")
      print(f"Average Deg Sum: {sum_deg_sum / count}")   #just to check
      print(f"Average Crossing Numbers Sum: {sum_cnb_sum / count}")
      print()

if __name__ == "__main__":
  main()
# Out:
# Filename: oregon2_010331.txt_5_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 98143.0
#
# Filename: z-alue7065.txt_3_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219351.0
#
# Filename: epinions1-d.txt_4_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1511572.0
#
# Filename: t.FLA-w.txt_4_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375796.0
#
# Filename: CAIDA_as_20130601.edgelist_2_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 448723.0
#
# Filename: z-alue7065.txt_4_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219344.0
#
# Filename: grid300-10.txt_2_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650094.0
#
# Filename: t.CAL-w.txt_2_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260874.0
#
# Filename: oregon2_010331.txt_9_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 96540.0
#
# Filename: grid300-10.txt_6_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650113.0
#
# Filename: t.CAL-w.txt_10_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260879.0
#
# Filename: z-alue7065.txt_5_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219336.0
#
# Filename: epinions1-d.txt_9_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1513089.0
#
# Filename: t.FLA-w.txt_9_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375785.0
#
# Filename: buddha-w.txt_4_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526217.0
#
# Filename: twitter_combined-d.txt_1_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4961253.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_6_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 100549.0
#
# Filename: grid300-10.txt_9_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650102.0
#
# Filename: t.FLA-w.txt_5_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375792.0
#
# Filename: dip20170205.edgelist_1_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280246.0
#
# Filename: notreDame-d.txt_2_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3822587.0
#
# Filename: buddha-w.txt_1_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526181.0
#
# Filename: powerlaw2.5.txt_5_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7475196.0
#
# Filename: froz-w.txt_3_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609842.0
#
# Filename: CAIDA_as_20130601.edgelist_5_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 448052.0
#
# Filename: CAIDA_as_20130601.edgelist_3_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 450945.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_10_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1091670.0
#
# Filename: epinions1-d.txt_7_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1511275.0
#
# Filename: notreDame-d.txt_1_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3822085.0
#
# Filename: com-dblp.ungraph.txt_8_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4114814.0
#
# Filename: grid300-10.txt_10_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650110.0
#
# Filename: froz-w.txt_5_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609934.0
#
# Filename: t.FLA-w.txt_1_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375783.0
#
# Filename: gnutella31-d.txt_1_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590490.0
#
# Filename: com-dblp.ungraph.txt_6_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4114477.0
#
# Filename: p2p-Gnutella09.edgelist_3_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101085.0
#
# Filename: y-BerkStan-d.txt_6_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20519892.0
#
# Filename: twitter_combined-d.txt_4_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4959737.0
#
# Filename: powerlaw2.5.txt_2_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7476635.0
#
# Filename: twitter_combined-d.txt_5_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4965811.0
#
# Filename: epinions1-d.txt_6_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1510697.0
#
# Filename: p2p-Gnutella09.edgelist_10_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 100961.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_9_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 104715.0
#
# Filename: xgrid500-10.txt_5_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803021.0
#
# Filename: xgrid500-10.txt_2_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803032.0
#
# Filename: notreDame-d.txt_10_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3830404.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_2_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1090757.0
#
# Filename: ca-HepPh.edgelist_6_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 256131.0
#
# Filename: epinions1-d.txt_10_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1509540.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_5_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 102544.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_8_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 103026.0
#
# Filename: froz-w.txt_7_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609906.0
#
# Filename: com-dblp.ungraph.txt_10_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4116241.0
#
# Filename: facebook_combined.txt_4_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 206760.0
#
# Filename: z-alue7065.txt_2_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219329.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_1_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 103184.0
#
# Filename: p2p-Gnutella09.edgelist_5_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101006.0
#
# Filename: CAIDA_as_20130601.edgelist_10_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 450389.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_6_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1089963.0
#
# Filename: notreDame-d.txt_6_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3830479.0
#
# Filename: ca-HepPh.edgelist_5_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 254391.0
#
# Filename: epinions1-d.txt_2_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1512189.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_7_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1092037.0
#
# Filename: t.CAL-w.txt_9_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260869.0
#
# Filename: t.FLA-w.txt_2_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375784.0
#
# Filename: froz-w.txt_10_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609958.0
#
# Filename: notreDame-d.txt_5_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3828040.0
#
# Filename: twitter_combined-d.txt_8_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4965504.0
#
# Filename: oregon2_010331.txt_2_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 97491.0
#
# Filename: com-dblp.ungraph.txt_9_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4115359.0
#
# Filename: notreDame-d.txt_9_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3824926.0
#
# Filename: com-dblp.ungraph.txt_1_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4114512.0
#
# Filename: t.CAL-w.txt_1_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260872.0
#
# Filename: oregon2_010331.txt_3_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 96845.0
#
# Filename: xgrid500-10.txt_8_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803030.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_7_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 257035.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_3_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256254.0
#
# Filename: twitter_combined-d.txt_6_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4956997.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_3_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 103962.0
#
# Filename: xgrid500-10.txt_1_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803029.0
#
# Filename: oregon2_010331.txt_6_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 97203.0
#
# Filename: t.FLA-w.txt_3_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375797.0
#
# Filename: com-dblp.ungraph.txt_5_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4113846.0
#
# Filename: dip20170205.edgelist_10_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280792.0
#
# Filename: gnutella31-d.txt_9_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590416.0
#
# Filename: y-BerkStan-d.txt_1_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20546939.0
#
# Filename: ca-HepPh.edgelist_7_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 255450.0
#
# Filename: froz-w.txt_1_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609922.0
#
# Filename: z-alue7065.txt_7_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219337.0
#
# Filename: notreDame-d.txt_3_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3826085.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_6_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256777.0
#
# Filename: facebook_combined.txt_9_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 208725.0
#
# Filename: oregon2_010331.txt_1_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 97344.0
#
# Filename: facebook_combined.txt_10_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 204689.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_4_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 257482.0
#
# Filename: y-BerkStan-d.txt_2_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20450322.0
#
# Filename: z-alue7065.txt_8_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219356.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_7_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 98944.0
#
# Filename: z-alue7065.txt_1_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219348.0
#
# Filename: t.CAL-w.txt_3_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260872.0
#
# Filename: froz-w.txt_4_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609912.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_2_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256666.0
#
# Filename: y-BerkStan-d.txt_10_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20429985.0
#
# Filename: buddha-w.txt_8_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526199.0
#
# Filename: epinions1-d.txt_5_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1510344.0
#
# Filename: froz-w.txt_9_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609923.0
#
# Filename: y-BerkStan-d.txt_5_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20573218.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_5_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1090505.0
#
# Filename: com-dblp.ungraph.txt_4_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4112635.0
#
# Filename: facebook_combined.txt_8_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 206230.0
#
# Filename: notreDame-d.txt_8_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3836266.0
#
# Filename: oregon2_010331.txt_8_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 97737.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_9_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256915.0
#
# Filename: buddha-w.txt_10_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526204.0
#
# Filename: epinions1-d.txt_1_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1510647.0
#
# Filename: facebook_combined.txt_1_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 206343.0
#
# Filename: twitter_combined-d.txt_3_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4963717.0
#
# Filename: xgrid500-10.txt_10_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803046.0
#
# Filename: t.FLA-w.txt_8_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375781.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_8_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256966.0
#
# Filename: grid300-10.txt_1_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650099.0
#
# Filename: oregon2_010331.txt_10_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 97343.0
#
# Filename: gnutella31-d.txt_4_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590415.0
#
# Filename: xgrid500-10.txt_7_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803024.0
#
# Filename: xgrid500-10.txt_9_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803041.0
#
# Filename: CAIDA_as_20130601.edgelist_9_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 446381.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_4_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 104941.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_1_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256536.0
#
# Filename: p2p-Gnutella09.edgelist_1_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101085.0
#
# Filename: t.CAL-w.txt_7_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260879.0
#
# Filename: p2p-Gnutella09.edgelist_8_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101047.0
#
# Filename: facebook_combined.txt_3_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 204997.0
#
# Filename: p2p-Gnutella09.edgelist_9_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101007.0
#
# Filename: gnutella31-d.txt_8_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590468.0
#
# Filename: powerlaw2.5.txt_3_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7477173.0
#
# Filename: buddha-w.txt_5_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526218.0
#
# Filename: gnutella31-d.txt_6_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590490.0
#
# Filename: froz-w.txt_6_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609872.0
#
# Filename: y-BerkStan-d.txt_4_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20507490.0
#
# Filename: t.CAL-w.txt_8_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260868.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_5_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256935.0
#
# Filename: facebook_combined.txt_5_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 206449.0
#
# Filename: p2p-Gnutella09.edgelist_6_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101110.0
#
# Filename: xgrid500-10.txt_3_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803030.0
#
# Filename: CAIDA_as_20130601.edgelist_8_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 443760.0
#
# Filename: buddha-w.txt_3_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526207.0
#
# Filename: com-dblp.ungraph.txt_3_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4114362.0
#
# Filename: grid300-10.txt_5_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650112.0
#
# Filename: gnutella31-d.txt_5_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590417.0
#
# Filename: grid300-10.txt_3_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650107.0
#
# Filename: CAIDA_as_20130601.edgelist_6_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 452884.0
#
# Filename: powerlaw2.5.txt_7_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7478236.0
#
# Filename: dip20170205.edgelist_9_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280110.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_9_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1090894.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_4_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1093560.0
#
# Filename: powerlaw2.5.txt_1_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7476773.0
#
# Filename: buddha-w.txt_2_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526216.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_10_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 101445.0
#
# Filename: t.FLA-w.txt_10_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375789.0
#
# Filename: dip20170205.edgelist_6_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280071.0
#
# Filename: froz-w.txt_2_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609810.0
#
# Filename: facebook_combined.txt_6_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 205181.0
#
# Filename: grid300-10.txt_4_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650110.0
#
# Filename: froz-w.txt_8_deg_cross.txt
# Average Deg Sum: 5805050.0
# Average Crossing Numbers Sum: 11609860.0
#
# Filename: as-skitter.txt_1_deg_cross.txt
# Average Deg Sum: 22190596.0
# Average Crossing Numbers Sum: 40641485.0
#
# Filename: twitter_combined-d.txt_9_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4959042.0
#
# Filename: ca-HepPh.edgelist_9_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 258868.0
#
# Filename: powerlaw2.5.txt_8_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7473509.0
#
# Filename: ca-HepPh.edgelist_8_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 252796.0
#
# Filename: CAIDA_as_20130601.edgelist_7_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 450333.0
#
# Filename: notreDame-d.txt_7_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3823641.0
#
# Filename: ca-HepPh.edgelist_4_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 251148.0
#
# Filename: t.FLA-w.txt_7_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375788.0
#
# Filename: com-dblp.ungraph.txt_7_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4115416.0
#
# Filename: buddha-w.txt_7_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526196.0
#
# Filename: p2p-Gnutella09.edgelist_7_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101030.0
#
# Filename: y-BerkStan-d.txt_7_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20436238.0
#
# Filename: CAIDA_as_20130601.edgelist_1_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 453248.0
#
# Filename: epinions1-d.txt_8_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1513621.0
#
# Filename: y-BerkStan-d.txt_8_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20319907.0
#
# Filename: facebook_combined.txt_7_deg_cross.txt
# Average Deg Sum: 176468.0
# Average Crossing Numbers Sum: 207143.0
#
# Filename: oregon2_010331.txt_7_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 95550.0
#
# Filename: gnutella31-d.txt_2_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590515.0
#
# Filename: z-alue7065.txt_10_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219339.0
#
# Filename: p2p-Gnutella09.edgelist_4_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 100964.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_1_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1090876.0
#
# Filename: epinions1-d.txt_3_deg_cross.txt
# Average Deg Sum: 811480.0
# Average Crossing Numbers Sum: 1513712.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-MS-3.5.169.edgelist_3_deg_cross.txt
# Average Deg Sum: 599710.0
# Average Crossing Numbers Sum: 1090286.0
#
# Filename: com-dblp.ungraph.txt_2_deg_cross.txt
# Average Deg Sum: 2099732.0
# Average Crossing Numbers Sum: 4119140.0
#
# Filename: CAIDA_as_20130601.edgelist_4_deg_cross.txt
# Average Deg Sum: 302868.0
# Average Crossing Numbers Sum: 449872.0
#
# Filename: notreDame-d.txt_4_deg_cross.txt
# Average Deg Sum: 2180216.0
# Average Crossing Numbers Sum: 3824953.0
#
# Filename: dip20170205.edgelist_4_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280443.0
#
# Filename: xgrid500-10.txt_4_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803033.0
#
# Filename: z-alue7065.txt_9_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219325.0
#
# Filename: dip20170205.edgelist_2_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280471.0
#
# Filename: xgrid500-10.txt_6_deg_cross.txt
# Average Deg Sum: 901532.0
# Average Crossing Numbers Sum: 1803028.0
#
# Filename: BIOGRID-SYSTEM-Affinity_Capture-RNA-3.5.169.edgelist_2_deg_cross.txt
# Average Deg Sum: 81082.0
# Average Crossing Numbers Sum: 107648.0
#
# Filename: dip20170205.edgelist_3_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280197.0
#
# Filename: buddha-w.txt_6_deg_cross.txt
# Average Deg Sum: 3263148.0
# Average Crossing Numbers Sum: 6526192.0
#
# Filename: powerlaw2.5.txt_4_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7475862.0
#
# Filename: twitter_combined-d.txt_7_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4959531.0
#
# Filename: y-BerkStan-d.txt_9_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20555669.0
#
# Filename: ca-HepPh.edgelist_3_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 256946.0
#
# Filename: dip20170205.edgelist_5_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280339.0
#
# Filename: t.FLA-w.txt_6_deg_cross.txt
# Average Deg Sum: 2687902.0
# Average Crossing Numbers Sum: 5375783.0
#
# Filename: t.CAL-w.txt_5_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260876.0
#
# Filename: dip20170205.edgelist_7_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280562.0
#
# Filename: y-BerkStan-d.txt_3_deg_cross.txt
# Average Deg Sum: 13298940.0
# Average Crossing Numbers Sum: 20430250.0
#
# Filename: powerlaw2.5.txt_10_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7473586.0
#
# Filename: t.CAL-w.txt_4_deg_cross.txt
# Average Deg Sum: 4630444.0
# Average Crossing Numbers Sum: 9260870.0
#
# Filename: z-alue7065.txt_6_deg_cross.txt
# Average Deg Sum: 109682.0
# Average Crossing Numbers Sum: 219321.0
#
# Filename: gnutella31-d.txt_10_deg_cross.txt
# Average Deg Sum: 295784.0
# Average Crossing Numbers Sum: 590516.0
#
# Filename: twitter_combined-d.txt_2_deg_cross.txt
# Average Deg Sum: 2684592.0
# Average Crossing Numbers Sum: 4961966.0
#
# Filename: oregon2_010331.txt_4_deg_cross.txt
# Average Deg Sum: 62360.0
# Average Crossing Numbers Sum: 98287.0
#
# Filename: p2p-Gnutella09.edgelist_2_deg_cross.txt
# Average Deg Sum: 52026.0
# Average Crossing Numbers Sum: 101229.0
#
# Filename: BIOGRID-MV-Physical-3.5.169.edgelist_10_deg_cross.txt
# Average Deg Sum: 136246.0
# Average Crossing Numbers Sum: 256434.0
#
# Filename: grid300-10.txt_7_deg_cross.txt
# Average Deg Sum: 325070.0
# Average Crossing Numbers Sum: 650116.0
#
# Filename: dip20170205.edgelist_8_deg_cross.txt
# Average Deg Sum: 147524.0
# Average Crossing Numbers Sum: 280322.0
#
# Filename: ca-HepPh.edgelist_2_deg_cross.txt
# Average Deg Sum: 236978.0
# Average Crossing Numbers Sum: 256552.0
#
# Filename: powerlaw2.5.txt_6_deg_cross.txt
# Average Deg Sum: 3832712.0
# Average Crossing Numbers Sum: 7475369.0

# %%
import os
import re

def main():
  folder_path = "../resap7"

  for filename in os.listdir(folder_path):
      file_path = os.path.join(folder_path, filename)
      with open(file_path, 'r') as f:
        content = f.read()  # Read the entire file content
        match = re.search(
          r"Crossing/stabbing number : (\d+) \(random :(\d+), bfs: (\d+)\)\n"
          r"Given order Crossing Number Sum= (\d+), Max Crossing Number=(\d+)\n"
          r"LowCross order Crossing Number Sum= (\d+), Max Crossing Number=(\d+)", 
          content, 
          re.MULTILINE
          )
        if match:
          filename_base1 = filename.rsplit('.')[0]
          filename_base = filename_base1.rsplit('.')[0]
          print(f"{filename_base} & {match.group(4)} & {match.group(6)} & {match.group(1)} & {match.group(2)} & {match.group(3)}\\\\")
          
      
if __name__ == "__main__":
  main()
# Out:
# CAIDA_as_20130601 & 676142 & 445350 & 472326 & 689972 & 562213\\
# com-dblp & 3963023 & 4559311 & 2884539 & 4833413 & 3164243\\
# grid300-10 & 506748 & 831272 & 641571 & 831295 & 553373\\
# BIOGRID-MV-Physical-3 & 304694 & 286442 & 238891 & 315756 & 256888\\
# p2p-Gnutella09 & 106984 & 116506 & 107049 & 120044 & 107021\\
# gnutella31-d & 617190 & 715592 & 634244 & 716603 & 618632\\
# dip20170205 & 348826 & 325935 & 287351 & 348813 & 293091\\
# BIOGRID-SYSTEM-Affinity_Capture-MS-3 & 1241487 & 1059858 & 1064727 & 1273144 & 1119378\\
# epinions1-d & 1573231 & 1590346 & 1560779 & 1770494 & 1558816\\
# xgrid500-10 & 1404022 & 2304958 & 1777529 & 2304966 & 1519918\\
# BIOGRID-SYSTEM-Affinity_Capture-RNA-3 & 166453 & 98995 & 108030 & 178734 & 126420\\
# twitter_combined-d & 5479672 & 4018636 & 3626607 & 5520794 & 4617659\\
# ca-HepPh & 485702 & 216454 & 165950 & 491858 & 277365\\
# oregon2_010331 & 139913 & 107915 & 108737 & 144226 & 117648\\
# facebook_combined & 307786 & 171245 & 164456 & 349813 & 303951\\
# z-alue7065 & 172070 & 287400 & 218823 & 287420 & 207081\\
